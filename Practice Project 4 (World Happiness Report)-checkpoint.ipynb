# %%
# Importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# Checking the the shape of data
df.shape
# Out:
# (158, 12)

# %%
# Checking the column names
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# **the dataset is having 158 rows and 12 columns**
# 1. Country and region are having object type column out of which the Country is ordinal which can be dropped (because it will not add any information to model and region is categorical column (after analysis we can come to an conclusion whether to drop or not)
# 2. Happiness Rank also can be dropped willnot add any information
# 3. the 4th column Happiness score is the target variable for us we have to predict that only
# 4. Rest of columns like 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual' are float type of columns which would be important to us

# %%
# deciding that column to be dropped or not
df['Country'].describe()
# Out:
# count             158
# unique            158
# top       Switzerland
# freq                1
# Name: Country, dtype: object

# %% [markdown]
# As this column only have name of the 158 countries will not be adding any information hence, I will be dropping

# %%
# deciding that column to be dropped or not
df['Happiness Rank'].describe()
# Out:
# count    158.000000
# mean      79.493671
# std       45.754363
# min        1.000000
# 25%       40.250000
# 50%       79.500000
# 75%      118.750000
# max      158.000000
# Name: Happiness Rank, dtype: float64

# %% [markdown]
# these are rank given according to max value of happiness score, will not add any information should be dropped

# %%
# checking data Type
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# All the columns are having the suitable/correct datatypes
# Hence there is no need to check for any void spaces in the data

# %%
# To check Central tendancy of the data
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# **Observations**
# 1. Happiness score column is the target variable
# 2. Standard error column is slightly rightskewed as mean is more than median
# 3. GDP per Capita is left skewed (negatively) seen as median is more than the mean
# 4. Family column is also left (negatively skewed) as median is more than the mean
# 5. health is left skewed as median is more than the mean
# 6. freedom is left skewed as median is more than the mean
# 7. Trust column is slightly rightskewed as mean is more than median
# 8. Generosity column is slightly rightskewed as mean is more than median
# 9. Dystopia is normally distributes seen from the describe function

# %%
# Checking for any null value present
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# It is seen that no null value is present, we will not deal for null value

# %% [markdown]
# # Data Visualization

# %% [markdown]
# **Univariate Analysis**

# %%
# Importing library
import seaborn as sns

# %%
sns.histplot(x='Standard Error', data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Count'>

# %% [markdown]
# standard error is rightskewed

# %%
sns.histplot(x='Economy (GDP per Capita)', data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Count'>

# %% [markdown]
# Economy (GDP per Capita) is left skewed

# %%
sns.histplot(x='Family', data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Count'>

# %% [markdown]
# Family is left skewed

# %%
sns.histplot(x='Health (Life Expectancy)', data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Count'>

# %% [markdown]
# Health (Life Expectancy) is left skewed

# %%
sns.histplot(x='Trust (Government Corruption)', data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Count'>

# %% [markdown]
# Trust (Government Corruption) is right skewed

# %%
sns.histplot(x='Generosity', data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Count'>

# %% [markdown]
# Generosity is right skewed

# %%
sns.histplot(x='Dystopia Residual', data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Count'>

# %% [markdown]
# dystopia is nearly normally distributed

# %% [markdown]
# **Bivariate analysis**

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x=df.index, y=df['Region'], hue=df['Happiness Score'])
# Out:
# <AxesSubplot:ylabel='Region'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=df['Happiness Score'], y=df['Region'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Region'>

# %% [markdown]
# **Observations**
# 1. From above two plots it is clear that Sub-saharan africa countries have lesser happiness compared to other
# 2. Western Europe countries have higher happines score and North America and new zealand too
# 3. Southeastern asia, central and easten Europe and eastern asia is having moderate happiness score from 4 to 7
# 4. Middle east, northen africa and are having happiness score from 4 to 7 only except one country

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Standard Error'], y=df['Happiness Score'], hue=df.Region)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %% [markdown]
# Standard error for maximum countries are ranging from 0.02 to 0.08, there are only 7 countries which are having standard error beyond 0.08

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Economy (GDP per Capita)'], y=df['Happiness Score'], hue=df.Region)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %% [markdown]
# It is clearly seen from the graph that if the economic growth means GDP increases then the happiness is also increasing.

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Family'], y=df['Happiness Score'], hue=df.Region)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %% [markdown]
# Family column is also shows that as the value increases the happiness score is also increasing

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Health (Life Expectancy)'], y=df['Happiness Score'], hue=df.Region)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %% [markdown]
# 1. It is clearly seen that from Sub saharan region the life expectancy is low hence happiness score is also low
# 2. Rest data is if Life expectancy increases the happiness score is also increasing

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Freedom'], y=df['Happiness Score'], hue=df.Region)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %% [markdown]
# If freedom is high then the happiness is also high.
# It is seen tahat the western europian countries has got freedom more has got higher happiness score

# %%
plt.figure(figsize=(12,7))
sns.barplot(x=df['Trust (Government Corruption)'], y=df['Region'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Region'>

# %% [markdown]
# the trust on the goverment is as follows from countries mentioned in the region (in Descending order) i.e(High trust to low trust)
# 1. Australia and New zealand
# 2. North America
# 3. Western Europe
# 4. Middle east and northen africa
# 5. southeastern asia
# 6. Eastern asia
# 7. Latin America and Caribbean
# 8. Sub -saharan africa
# 9. southern asia
# 10. central and eastern Europe

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Trust (Government Corruption)'], y=df['Happiness Score'], hue=df.Region)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %% [markdown]
# According to region we can conclude that
# 1. if there is low trust on govt. then low happiness score for Sub saharan and central eastern europe
# 2. if there is high trust on govt. then high happiness score seen for Western Europe and Australia and New Zealand and some countries from middle east and northen africa

# %%
plt.figure(figsize=(12,7))
sns.barplot(x=df['Happiness Score'], y=df['Region'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Region'>

# %% [markdown]
# 1. countries in north America and Westren Europe has high happiness Score followed by western Europe, latin America, eastern asia
# 2. low happiness score seen from sub saharan countries

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Generosity'], y=df['Happiness Score'], hue=df.Region)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %% [markdown]
# If generosity is low low happiness score seen from sub saharan africa
# if generosity is high then high happiness score seen from north america , australia and new zealand and western Europe

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=df['Dystopia Residual'], y=df['Happiness Score'], hue=df.Region)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %% [markdown]
# from graph it seen that if the dystopia residual increase the happiness score increases

# %% [markdown]
# **correlation between the columns**

# %%
corr_mat=df.corr()
corr_mat
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(12,7))
sns.heatmap(corr_mat,annot=True)
# Out:
# <AxesSubplot:>

# %%
corr_mat['Happiness Score'].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Standard Error                  -0.177254
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %% [markdown]
# **Observation**
# 1. **Economy, family and Health (Life Expectancy) is highly correlated with happiness score with 78.09%, 74.06% and 72.42% respectively**
# 2. Freedom and Dystopia residual is moderately correlated with Happiness score with 56.82% and 53.04%
# 3. Trust is also having moderate correlation with happiness score with 39.51%
# 4. Generosity is having very low correlation with happiness score at 18.03%
# 5. standard Error is negatively correlated with happiness score at 17.72.

# %% [markdown]
# **Observation about Multi collinearity**
# we will check for multicolinearity by vif because GDP and Family are highly corelated with each other in preprocessing

# %% [markdown]
# **Checking for skewness for the dataset**

# %%
df.skew().sort_values(ascending=False)
# Out:
# Standard Error                   1.983439
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Happiness Score                  0.097769
# Happiness Rank                   0.000418
# Dystopia Residual               -0.238911
# Economy (GDP per Capita)        -0.317575
# Freedom                         -0.413462
# Health (Life Expectancy)        -0.705328
# Family                          -1.006893
# dtype: float64

# %% [markdown]
# **Observations**
# 1. standard error , trust, generosity are positively skewed
# 2. Dystopia Residual, Economy (GDP per Capita),Freedom, Health (Life Expectancy) and Family are negatively skewed
#
# this has to be handled in preprocessing

# %% [markdown]
# **detecting Outliers**
# we can use the box plot to see whether outliers are present or not

# %%
# Taking Box plot
plt.figure(figsize=(12,7))
df.plot(kind='box', subplots=True, layout=(2,5))
# Out:
# Happiness Rank                      AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Happiness Score                  AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Standard Error                    AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# Economy (GDP per Capita)         AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Family                           AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Health (Life Expectancy)               AxesSubplot(0.125,0.125;0.133621x0.343182)
# Freedom                             AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Trust (Government Corruption)        AxesSubplot(0.44569,0.125;0.133621x0.343182)
# Generosity                          AxesSubplot(0.606034,0.125;0.133621x0.343182)
# Dystopia Residual                   AxesSubplot(0.766379,0.125;0.133621x0.343182)
# dtype: object

# %% [markdown]
# from above box plots it can be said that
# 1. in Standard error the outliers are present
# 2. in trust the outliers are ppresent
# 3. Family outliers are present
# 4. generosity the outliers are present
# 5. Dystopia the outliers are present
#
# **It can be handled in the Preprocessing**

# %% [markdown]
# # Preprocessing of the data

# %% [markdown]
# **Removing unncessary columns**

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df=df.drop(['Country','Happiness Rank'],axis=1)

# %%
df
# Out:
#                               Region  Happiness Score  Standard Error  \
# 0                     Western Europe            7.587         0.03411
# 1                     Western Europe            7.561         0.04884
# 2                     Western Europe            7.527         0.03328
# 3                     Western Europe            7.522         0.03880
# 4                      North America            7.427         0.03553
# ..                               ...              ...             ...
# 153               Sub-Saharan Africa            3.465         0.03464
# 154               Sub-Saharan Africa            3.340         0.03656
# 155  Middle East and Northern Africa            3.006         0.05015
# 156               Sub-Saharan Africa            2.905         0.08658
# 157               Sub-Saharan Africa            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# **Encoding the data for only region**
# As seen earlier the regional aspect plays an important role, the conclusion from visualization technique is to keep the region column to see the geographical advantages and dis advantages to see their effect

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Region']=le.fit_transform(df.Region)
df
# Out:
#      Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0         9            7.587         0.03411                   1.39651
# 1         9            7.561         0.04884                   1.30232
# 2         9            7.527         0.03328                   1.32548
# 3         9            7.522         0.03880                   1.45900
# 4         5            7.427         0.03553                   1.32629
# ..      ...              ...             ...                       ...
# 153       8            3.465         0.03464                   0.22208
# 154       8            3.340         0.03656                   0.28665
# 155       4            3.006         0.05015                   0.66320
# 156       8            2.905         0.08658                   0.01530
# 157       8            2.839         0.06727                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# ...

# %%
df.shape
# Out:
# (158, 10)

# %% [markdown]
# **Removing outliers from the dataset**
# By Zscore method

# %%
# Importing Library for it
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 10)

# %%
#setting threshold at 3 and equating checking for z>3
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
#removing the outliers
df_new=df[(z<3).all(axis=1)]
df_new.shape
# Out:
# (149, 10)

# %%
# calcuating dataloss
loss=(158-149)/158*100
loss
# Out:
# 5.69620253164557

# %% [markdown]
# **since the data loss is only 5.69% we can delet the data**

# %%
df=df_new

# %%
df.shape
# Out:
# (149, 10)

# %%
#separating the input variable and target variable
x=df.drop(['Happiness Score'],axis=1)
x.shape
# Out:
# (149, 9)

# %%
y=df['Happiness Score']
y.shape
# Out:
# (149,)

# %% [markdown]
# **Removing skewness using Power transform**

# %%
#importing Powertransform
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 1.23451354, -0.95033703,  1.49245411, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [ 1.23451354,  0.37856182,  1.19406711, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [ 1.23451354, -1.04140135,  1.26661161, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [ 0.66673577, -1.32081011, -1.36521585, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [ 0.95527966, -0.69272644, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 0.95527966,  2.17876604, -1.93874732, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %%
#checking for skewness is removed or not
skew_df=pd.DataFrame(x)
skew_df.skew()
# Out:
# 0   -0.222589
# 1   -0.031216
# 2   -0.140644
# 3   -0.148528
# 4   -0.190663
# 5   -0.076489
# 6    0.174593
# 7    0.025172
# 8    0.014748
# dtype: float64

# %% [markdown]
# As we can see that the data is having skewness is in the range of -0.2 to 0.2. it is now acceptable range

# %% [markdown]
# **Scaling the data**

# %%
#importing the StandardScaler
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)
x
# Out:
# array([[ 1.23451354, -0.95033703,  1.49245411, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [ 1.23451354,  0.37856182,  1.19406711, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [ 1.23451354, -1.04140135,  1.26661161, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [ 0.66673577, -1.32081011, -1.36521585, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [ 0.95527966, -0.69272644, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 0.95527966,  2.17876604, -1.93874732, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %% [markdown]
# **To see the VIFs of each coloumn**

# %%
#importing the VIF in jupyter
from statsmodels.stats.outliers_influence import variance_inflation_factor
new_df=pd.DataFrame(x)
def vif_scores(df):
    VIF_Scores = pd.DataFrame()
    VIF_Scores["Independent Features"] = new_df.columns
    VIF_Scores["VIF Scores"] = [variance_inflation_factor(new_df.values,i) for i in range(new_df.shape[1])]
    return VIF_Scores
df1 = new_df
vif_scores(df1)
# Out:
#    Independent Features  VIF Scores
# 0                     0    1.349527
# 1                     1    1.155490
# 2                     2    4.728896
# 3                     3    2.142563
# 4                     4    4.271936
# 5                     5    2.134052
# 6                     6    1.483354
# 7                     7    1.506637
# 8                     8    1.047779

# %% [markdown]
# **As we can see that the VIf values are less than 5 so we can proceed with data what we have for further analysis**

# %% [markdown]
# # Modelling the data

# %% [markdown]
# As the target column type is continuous we will apply the linear regression algorithm

# %%
# importing Linear Regression and metrics for it
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# Finding out best random state with linear regression model

# %%
maxr2=0
maxrs=0
lr=LinearRegression()
for i in range(0,200):
    print("Random State is ", i)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(xtrain,ytrain)
    predtrain=lr.predict(xtrain)
    predtest=lr.predict(xtest)
    print('training accuracy is ', r2_score(ytrain,predtrain))
    score=r2_score(ytest,predtest)
    print('testing accuracy is ', score)
    print("\n")
    
    if score>maxr2:
        maxr2=score
        maxrs=i
        
        
print("maximum r2 score is ", maxr2 , "at random state ", maxrs)
# Out:
# Random State is  0
# training accuracy is  0.9951293562737327
# testing accuracy is  0.995931379752898
#
#
# Random State is  1
# training accuracy is  0.9948703091759132
# testing accuracy is  0.9973524376788055
#
#
# Random State is  2
# training accuracy is  0.9956135822054418
# testing accuracy is  0.9935109606444624
#
#
# Random State is  3
# training accuracy is  0.9953970699372042
# testing accuracy is  0.9941857997637882
#
#
# Random State is  4
# training accuracy is  0.9949937523132236
# testing accuracy is  0.9952123180881637
#
#
# Random State is  5
# training accuracy is  0.9957074024471709
# testing accuracy is  0.9923759099099871
#
#
# Random State is  6
# training accuracy is  0.9964440295935055
# testing accuracy is  0.9892794187336061
#
#
# Random State is  7
# training accuracy is  0.9960744214900451
# testing accuracy is  0.9882815169967559
#
#
# Random State is  8
# training accuracy is  0.9953233991701477
# testing accuracy is  0.9944352278175377
#
#
# ...

# %% [markdown]
# **It can be noted that the maximum r2 score is coming out to be 0.998275027711325 at random state 60**

# %% [markdown]
# splitting the model in to train test split according to above result

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=60)

# %%
#running that same model again for other metrics too
lr.fit(x_train,y_train)
predtrainlr=lr.predict(x_train)
predtestlr=lr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainlr))
print('testing accuracy is ', r2_score(y_test,predtestlr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestlr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestlr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestlr)))
# Out:
# training accuracy is  0.9943972426758774
# testing accuracy is  0.998275027711325
# Mean Squared Error is  0.0023114680973237663
# Mean Absolute Error is  0.04174508576658194
# Root Mean Squared Error is  0.048077729743861305

# %%
from sklearn.model_selection import cross_val_score
#Cross validation of the lr model
for j in range(2,10):
    cv_score=cross_val_score(lr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
    print('training accuracy is ', r2_score(y_train,predtrainlr))
    print('testing accuracy is ', r2_score(y_test,predtestlr))
# Out:
# At fold  2 Mean CV score is  0.8725438407510111
# training accuracy is  0.9943972426758774
# testing accuracy is  0.998275027711325
# At fold  3 Mean CV score is  0.9113644114827402
# training accuracy is  0.9943972426758774
# testing accuracy is  0.998275027711325
# At fold  4 Mean CV score is  0.8671832997779907
# training accuracy is  0.9943972426758774
# testing accuracy is  0.998275027711325
# At fold  5 Mean CV score is  0.857740770439938
# training accuracy is  0.9943972426758774
# testing accuracy is  0.998275027711325
# At fold  6 Mean CV score is  0.795525648706524
# training accuracy is  0.9943972426758774
# testing accuracy is  0.998275027711325
# At fold  7 Mean CV score is  0.6892003699544443
# training accuracy is  0.9943972426758774
# testing accuracy is  0.998275027711325
# At fold  8 Mean CV score is  0.6565126492263065
# training accuracy is  0.9943972426758774
# testing accuracy is  0.998275027711325
# At fold  9 Mean CV score is  0.5737466991167813
# ...

# %% [markdown]
# **Because the data set is very small the Cv at 3 is giving good cross val score**

# %%
# modelling using the Decision tree regressor
from sklearn.tree import DecisionTreeRegressor

dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
predtraindtr=dtr.predict(x_train)
predtestdtr=dtr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtraindtr))
print('testing accuracy is ', r2_score(y_test,predtestdtr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestdtr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestdtr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestdtr)))
# Out:
# training accuracy is  1.0
# testing accuracy is  0.7548065001103327
# Mean Squared Error is  0.3285600333333332
# Mean Absolute Error is  0.46083333333333326
# Root Mean Squared Error is  0.5732015643151485

# %%
#Cross validation of the dtr model
dtr=DecisionTreeRegressor()
for j in range(2,10):
    cvdtr=cross_val_score(dtr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cvdtr.mean())
# Out:
# At fold  2 Mean CV score is  -3.9423691361697033
# At fold  3 Mean CV score is  -3.9362656808556884
# At fold  4 Mean CV score is  -8.846040253758034
# At fold  5 Mean CV score is  -8.474048671220931
# At fold  6 Mean CV score is  -11.399721890506394
# At fold  7 Mean CV score is  -18.763671880574652
# At fold  8 Mean CV score is  -19.308336977037097
# At fold  9 Mean CV score is  -23.213670707858306

# %%
# Modelling with randomForestRegressor

from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predtrainrfr=rfr.predict(x_train)
predtestrfr=rfr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainrfr))
print('testing accuracy is ', r2_score(y_test,predtestrfr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestrfr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestrfr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestrfr)))
# Out:
# training accuracy is  0.9859409833775882
# testing accuracy is  0.9310185972365241
# Mean Squared Error is  0.09243528886999994
# Mean Absolute Error is  0.2323403333333333
# Root Mean Squared Error is  0.30403172345990465

# %%
#Cross validation of the rfr model
for j in range(2,10):
    cv_score=cross_val_score(rfr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  -4.213116156859189
# At fold  3 Mean CV score is  -2.806472753873822
# At fold  4 Mean CV score is  -4.383046876764039
# At fold  5 Mean CV score is  -3.6739355341215187
# At fold  6 Mean CV score is  -4.70343224631441
# At fold  7 Mean CV score is  -4.923822623679132
# At fold  8 Mean CV score is  -7.440157606920583
# At fold  9 Mean CV score is  -6.661019584828643

# %%
# modelling with ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesRegressor

etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
predtrainetr=etr.predict(x_train)
predtestetr=etr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainetr))
print('testing accuracy is ', r2_score(y_test,predtestetr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestetr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestetr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestetr)))
# Out:
# training accuracy is  1.0
# testing accuracy is  0.9495693636369874
# Mean Squared Error is  0.0675772056433331
# Mean Absolute Error is  0.19372499999999984
# Root Mean Squared Error is  0.25995616100283736

# %%
#Cross validation of the etr model
for j in range(2,10):
    cv_score=cross_val_score(etr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  -3.9730883993294346
# At fold  3 Mean CV score is  -2.831872415154469
# At fold  4 Mean CV score is  -3.852843676559135
# At fold  5 Mean CV score is  -3.0892602993721283
# At fold  6 Mean CV score is  -4.0344748067072045
# At fold  7 Mean CV score is  -4.262067581195985
# At fold  8 Mean CV score is  -6.29769905106996
# At fold  9 Mean CV score is  -6.3434296395406555

# %%
# Modelling with SVR

from sklearn.svm import SVR

svr=SVR()
svr.fit(x_train,y_train)
predtrainsvr=svr.predict(x_train)
predtestsvr=svr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainsvr))
print('testing accuracy is ', r2_score(y_test,predtestsvr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestsvr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestsvr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestsvr)))
# Out:
# training accuracy is  0.9843427542530215
# testing accuracy is  0.9719479360887834
# Mean Squared Error is  0.03758985070112179
# Mean Absolute Error is  0.14658118675053564
# Root Mean Squared Error is  0.19388102202413157

# %%
#Cross validation of the svr model
for j in range(2,10):
    cv_score=cross_val_score(svr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  -4.159819514631748
# At fold  3 Mean CV score is  -2.901405414913563
# At fold  4 Mean CV score is  -3.2744695772775296
# At fold  5 Mean CV score is  -3.282193654796157
# At fold  6 Mean CV score is  -2.803899475949686
# At fold  7 Mean CV score is  -2.7930605386734806
# At fold  8 Mean CV score is  -3.3472959037301973
# At fold  9 Mean CV score is  -3.305044387824385

# %%
# modelling with .KNeighborsRegressor
from sklearn.neighbors import KNeighborsRegressor

knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
predtrainknr=knr.predict(x_train)
predtestknr=knr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainknr))
print('testing accuracy is ', r2_score(y_test,predtestknr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestknr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestknr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestknr)))
# Out:
# training accuracy is  0.9174402097893162
# testing accuracy is  0.8909549422752591
# Mean Squared Error is  0.14612070800000013
# Mean Absolute Error is  0.30398
# Root Mean Squared Error is  0.38225738449374674

# %%
# Modeling for gradient boosting regresssor
from sklearn.ensemble import GradientBoostingRegressor

gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
predtraingbr=gbr.predict(x_train)
predtestgbr=gbr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtraingbr))
print('testing accuracy is ', r2_score(y_test,predtestgbr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestgbr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestgbr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestgbr)))
# Out:
# training accuracy is  0.9991160102454532
# testing accuracy is  0.931605491476416
# Mean Squared Error is  0.09164884880895106
# Mean Absolute Error is  0.19163421747471526
# Root Mean Squared Error is  0.30273560875614064

# %%
#Cross validation of the gbr model
for j in range(2,10):
    cv_score=cross_val_score(gbr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  -2.782494003642873
# At fold  3 Mean CV score is  -1.6372090722402295
# At fold  4 Mean CV score is  -2.819553821306472
# At fold  5 Mean CV score is  -2.4698595971180444
# At fold  6 Mean CV score is  -3.0305036916218158
# At fold  7 Mean CV score is  -3.4740235204640535
# At fold  8 Mean CV score is  -4.2980538747435935
# At fold  9 Mean CV score is  -4.982723870358784

# %% [markdown]
# **The cross val Score for the other models are negative except Linear Rehgression model**
# I have raised ticket to get this problem clear but have not got any reply till 6.pm 8/01/23
#
# **Hence proceeding further with Linear equation** model for which i got higher r2 score

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.model_selection import GridSearchCV

# %%
# Doing Lasso Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'tol': [0.001,0.0001,0.00001,0.000001]}

ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'max_iter': 100, 'random_state': 0, 'tol': 0.001}

# %%
ls=Lasso(alpha=0.001, max_iter=100, random_state=0, tol=0.001)
ls.fit(x_train,y_train)
predtrainls=ls.predict(x_train)
predtestls=ls.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainls))
print('testing accuracy is ', r2_score(y_test,predtestls))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestls))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestls))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestls)))
# Out:
# training accuracy is  0.9943928936845327
# testing accuracy is  0.9983028932025966
# Mean Squared Error is  0.0022741282545254713
# Mean Absolute Error is  0.04142762794009875
# Root Mean Squared Error is  0.04768782081963351

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_score=cross_val_score(ls, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.8755494579919889
# At fold  3 Mean CV score is  0.911876413408252
# At fold  4 Mean CV score is  0.8680145529879904
# At fold  5 Mean CV score is  0.8578916864011632
# At fold  6 Mean CV score is  0.795968824534475
# At fold  7 Mean CV score is  0.6900505740157161
# At fold  8 Mean CV score is  0.659380869909628
# At fold  9 Mean CV score is  0.5774535387703599

# %% [markdown]
# **Cross val score for the fold 3 is giving very good accuracy**

# %%
# Doing Ridge Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']}

rg=Ridge()
clf=GridSearchCV(rg,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1e-05, 'max_iter': 10, 'random_state': 2, 'solver': 'saga'}

# %%
rg=Ridge(alpha=0.00001, max_iter=10, random_state=2, solver='saga')
rg.fit(x_train,y_train)
predtrainrg=rg.predict(x_train)
predtestrg=rg.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainrg))
print('testing accuracy is ', r2_score(y_test,predtestrg))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestrg))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestrg))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestrg)))
# Out:
# training accuracy is  0.9943898102362608
# testing accuracy is  0.9983163131975945
# Mean Squared Error is  0.002256145420535898
# Mean Absolute Error is  0.04186219381861658
# Root Mean Squared Error is  0.047498899150779254

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_score=cross_val_score(rg, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.8704037082351823
# At fold  3 Mean CV score is  0.9098697564625232
# At fold  4 Mean CV score is  0.8669881225591467
# At fold  5 Mean CV score is  0.8574978274704016
# At fold  6 Mean CV score is  0.7976646401947446
# At fold  7 Mean CV score is  0.6924306010262683
# At fold  8 Mean CV score is  0.655029072475258
# At fold  9 Mean CV score is  0.5652397707495674

# %% [markdown]
# **Cross val score for the fold 3 is giving very good accuracy**

# %% [markdown]
# # Saving the Model

# %% [markdown]
# **As the ridge model is giving higher accuracy saving that model**

# %%
import joblib
joblib.dump(Ridge(alpha=0.00001, max_iter=10, random_state=2, solver='saga'), "world_happiness_report.pkl")
# Out:
# ['world_happiness_report.pkl']

# %% [markdown]
# # Conclusion

# %%
a=np.array(y_test)
predicted=np.array(predtestrg)
df_con=pd.DataFrame({'Original':a,'Predicted':predicted}, index=range(len(a)))
df_con
# Out:
#     Original  Predicted
# 0      6.505   6.545347
# 1      4.252   4.230036
# 2      3.956   3.921070
# 3      4.565   4.630085
# 4      3.904   3.839297
# 5      5.759   5.713022
# 6      5.429   5.483845
# 7      3.989   3.957058
# 8      5.360   5.290172
# 9      7.427   7.460468
# 10     6.295   6.360964
# 11     4.033   4.047393
# 12     5.695   5.702126
# 13     5.890   5.830464
# 14     6.983   6.958009
# 15     6.411   6.332113
# 16     6.302   6.322580
# 17     5.833   5.817779
# 18     6.798   6.749832
# 19     4.077   4.046917
# 20     7.119   7.199610
# 21     6.901   6.869311
# 22     7.522   7.559163
# 23     4.642   4.614698
# 24     5.123   5.102415
# 25     5.975   5.902480
# 26     4.297   4.285165
# 27     4.694   4.744865
# 28     5.192   5.110199
# 29     3.681   3.694457

# %% [markdown]
# **From this we can see that model is predicting happiness score quite good for the testing data**
