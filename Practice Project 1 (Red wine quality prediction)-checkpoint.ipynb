# %% [markdown]
# # Red Wine Quality Prediction

# %% [markdown]
# # Problem Statement:
#
# The dataset is related to red and white variants of the Portuguese "Vinho Verde" wine. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# This dataset can be viewed as classification task. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.

# %%
# Importing Libraries I will be using for project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading database

# %%
#  from github directly
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# checking names of all columns
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Checking data types of all columns
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# Information about the dataset
#
# Input variables (based on physicochemical tests):
#
# 1. fixed acidity
# 2. volatile acidity
# 3. citric acid
# 4. residual sugar
# 5. chlorides
# 6. free sulfur dioxide
# 7. total sulfur dioxide
# 8. density
# 9. pH
# 10. sulphates
# 11. alcohol

# %%
# checking shape of data
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# We have 1599 rows and 12columns (including the target column)

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# Output variable (based on sensory data):
# 12 - quality (score between 3 and 8)

# %%
# checking for any null value
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Heatmap for null values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# **No null value present hence moving to next step**

# %%
# to check the data by describe function

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# **Observations from Describe function**
# 1. Input parameter volatile acidity, citric acid, free sulfur-dioxide, density, ph, sulphates and alcohol are having almost same **mean** and **median**
# 2. Input data fixed acidity, residual sugar, chloride, total sulphur dioxide are slightly right skewed from observation beacuse for these datas mean is more than median

# %% [markdown]
# # Adding one column target in data for
# if the quality value 7 and more its a 'Good quality wine' and if quality is less than that then its'not Good quality'

# %%
# adding target column
df["target"] = np.where(df["quality"] > 6, 1, 0)

# %%
df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1112            7.9             0.330         0.41             1.5      0.056
# 651             9.8             0.880         0.25             2.5      0.104
# 1279            9.8             0.300         0.39             1.7      0.062
# 329            10.7             0.460         0.39             2.0      0.061
# 1280            7.1             0.460         0.20             1.9      0.077
# 711             8.9             0.565         0.34             3.0      0.093
# 160             7.6             0.950         0.03             2.0      0.090
# 197            11.5             0.300         0.60             2.0      0.067
# 694             9.0             0.470         0.31             2.7      0.084
# 200             9.6             0.320         0.47             1.4      0.056
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# # Univariate Analysis

# %%
sns.pairplot(df)

# %% [markdown]
# **Observation from Univariate analysis**
# 1. fixed acidity is equally distributed from 0 to 13
# 2. volatile  acidity is equally distributed from 0 to 1
# 3. citric acid is equally distributed from 0 to 0.80
# 4. residual sugar is equally distributed from 0 to 9
# 5. chloride is equally distributed from 0 to 0.2
# 6. Free sulphur dioxide is equally distributed from 0 to 50
# 7. total sulphur dioxide is equally distributed from 0 to 130
# 8. density is equally distributed from 0.99 to 1.02
# 9. pH is equally distributed from 2.7 to 3.7
# 10. sulphate is equally distributed from 0 to1.4
# 11. alcohol is equally distributed from 9 to 14
#
# **also we can see that some of the inputs are nearly normal distributed as cited from describe function**

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# **Correlation**

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
# target                     0.120061         -0.270712     0.214716
#
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
cor_mat=df.corr()

# %%
cor_mat['target'].sort_values(ascending=False)
# Out:
# target                  1.000000
# quality                 0.710196
# alcohol                 0.407315
# citric acid             0.214716
# sulphates               0.199485
# fixed acidity           0.120061
# residual sugar          0.047779
# pH                     -0.057283
# free sulfur dioxide    -0.071747
# chlorides              -0.097308
# total sulfur dioxide   -0.139517
# density                -0.150460
# volatile acidity       -0.270712
# Name: target, dtype: float64

# %% [markdown]
# **from above following observations can be drawn**
# 1. alcohol is 40.73% positively moderately correlated with target wine quality (Good and Not Good)
# 2. citric acid is 21.47% positively low correlated with target wine quality (Good and Not Good)
# 3. sulphates is 19.99% positively low correlated with target wine quality (Good and Not Good)
# 4. fixed acidity is 12.01% positively very low correlated with target wine quality (Good and Not Good)
# 5. residual sugar is 4.77% positively very very low correlated with target wine quality (Good and Not Good)
# 6. pH is 5.77% negatively very very low correlated with target wine quality (Good and Not Good)
# 7. free sulphur chloride is 7.17% negatively very very low correlated with target wine quality (Good and Not Good)
# 8. chloride is 9.73% negatively very low correlated with target wine quality (Good and Not Good)
# 9. total sulphur dioxide is 13.95% negatively very low correlated with target wine quality (Good and Not Good)
# 10. density is 15.04% negatively very low correlated with target wine quality (Good and Not Good)
# 11. volatile acidity is 27.07% negatively moderately low correlated with target wine quality (Good and Not Good)

# %% [markdown]
# **cheking for distribution**

# %%
df.plot(kind='density', subplots=True, layout=(6,3), sharex=False, legend=True, fontsize=2,figsize=(20,15))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# target                  2.129363
# dtype: float64

# %% [markdown]
# **residual sugar, chlorides, free sulphur dioxide and total sulphur dioxide, sulphates, target are right-skewed with different values**

# %% [markdown]
# **Outliers Cheking**

# %%
# Checking for outliers using box-plot
df.plot(kind='box',subplots=True, layout=(2,7))
# Out:
# fixed acidity              AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# volatile acidity        AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# citric acid             AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# residual sugar          AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# chlorides               AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# free sulfur dioxide     AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# total sulfur dioxide    AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# density                       AxesSubplot(0.125,0.125;0.0945122x0.343182)
# pH                         AxesSubplot(0.238415,0.125;0.0945122x0.343182)
# sulphates                  AxesSubplot(0.351829,0.125;0.0945122x0.343182)
# alcohol                    AxesSubplot(0.465244,0.125;0.0945122x0.343182)
# quality                    AxesSubplot(0.578659,0.125;0.0945122x0.343182)
# target                     AxesSubplot(0.692073,0.125;0.0945122x0.343182)
# ...

# %% [markdown]
# **outliers are present in the data**

# %% [markdown]
# # Preprocessing the data

# %% [markdown]
# **Dropping columns which are having very very low correlation with our quality or target and having outliers too and skewed also**

# %%
df=df.drop(['residual sugar','chlorides','free sulfur dioxide', ],axis=1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  total sulfur dioxide  \
# 0               7.4             0.700         0.00                  34.0
# 1               7.8             0.880         0.00                  67.0
# 2               7.8             0.760         0.04                  54.0
# 3              11.2             0.280         0.56                  60.0
# 4               7.4             0.700         0.00                  34.0
# ...             ...               ...          ...                   ...
# 1594            6.2             0.600         0.08                  44.0
# 1595            5.9             0.550         0.10                  51.0
# 1596            6.3             0.510         0.13                  40.0
# 1597            5.9             0.645         0.12                  44.0
# 1598            6.0             0.310         0.47                  42.0
#
#       density    pH  sulphates  alcohol  quality  target
# ...

# %%
df.shape
# Out:
# (1599, 10)

# %%
x=df.iloc[:,0:-2]
y=df.iloc[:,-1]

# %%
x.shape
# Out:
# (1599, 8)

# %%
y.shape
# Out:
# (1599,)

# %% [markdown]
# **removing outliers fromdataset**

# %%
# by Zscore method
# importing required libraries
from scipy.stats import zscore

# %%
z=np.abs(zscore(x))
z.shape
# Out:
# (1599, 8)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   15,   17,   38,   43,   45,   81,   86,   88,   91,   92,
#          95,  106,  109,  120,  126,  127,  142,  144,  151,  151,  151,
#         169,  199,  226,  243,  244,  258,  339,  340,  347,  354,  374,
#         381,  391,  442,  442,  467,  480,  515,  544,  554,  554,  555,
#         555,  557,  557,  588,  591,  608,  614,  636,  639,  649,  651,
#         652,  652,  672,  672,  684,  690,  692,  695,  723,  724,  795,
#         821,  836,  837,  889, 1017, 1018, 1051, 1079, 1081, 1111, 1114,
#        1244, 1269, 1269, 1270, 1270, 1288, 1289, 1299, 1300, 1312, 1316,
#        1319, 1321, 1367, 1370, 1372, 1434, 1435, 1474, 1476, 1493, 1496],
#       dtype=int64), array([6, 3, 6, 1, 6, 5, 6, 6, 6, 6, 6, 5, 6, 3, 1, 1, 1, 7, 7, 2, 5, 6,
#        6, 1, 6, 0, 0, 6, 6, 6, 0, 3, 0, 0, 0, 0, 4, 7, 4, 3, 0, 0, 4, 0,
#        4, 0, 4, 7, 3, 4, 6, 3, 6, 3, 3, 0, 7, 1, 3, 3, 1, 6, 5, 6, 1, 6,
#        7, 4, 4, 4, 4, 4, 6, 3, 3, 5, 4, 3, 4, 7, 4, 7, 6, 6, 1, 5, 1, 5,
# ...

# %%
x=x[(z<3).all(axis=1)]
x.shape
# Out:
# (1510, 8)

# %%
y=y[(z<3).all(axis=1)]
y.shape
# Out:
# (1510,)

# %%
# calculating percentage data loss
loss=(1599-1510)/1599*100
loss
# Out:
# 5.565978736710444

# %% [markdown]
# **the data loss is 5.56% is may be fall under acceptable range**

# %% [markdown]
# **Removing Skewness** using PowerTransform

# %%
# Importing library to use PoerTransform
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.4570752 ,  1.04279539, -1.52528722, ...,  1.36523189,
#         -0.58848116, -1.09744421],
#        [-0.15909191,  1.90833503, -1.52528722, ..., -0.80905476,
#          0.4379732 , -0.50964469],
#        [-0.15909191,  1.34420798, -1.24624921, ..., -0.37502775,
#          0.21092672, -0.50964469],
#        ...,
#        [-1.44569039, -0.01241541, -0.66765589, ...,  0.75096923,
#          0.90519212,  0.75717321],
#        [-1.88369139,  0.75393579, -0.72886041, ...,  1.76745809,
#          0.64827431, -0.01570259],
#        [-1.76947858, -1.33065261,  1.06382154, ...,  0.54321995,
#          0.28856896,  0.75717321]])

# %% [markdown]
# **Scaling the data**

# %%
# importing libraries
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.4570752 ,  1.04279539, -1.52528722, ...,  1.36523189,
#         -0.58848116, -1.09744421],
#        [-0.15909191,  1.90833503, -1.52528722, ..., -0.80905476,
#          0.4379732 , -0.50964469],
#        [-0.15909191,  1.34420798, -1.24624921, ..., -0.37502775,
#          0.21092672, -0.50964469],
#        ...,
#        [-1.44569039, -0.01241541, -0.66765589, ...,  0.75096923,
#          0.90519212,  0.75717321],
#        [-1.88369139,  0.75393579, -0.72886041, ...,  1.76745809,
#          0.64827431, -0.01570259],
#        [-1.76947858, -1.33065261,  1.06382154, ...,  0.54321995,
#          0.28856896,  0.75717321]])

# %% [markdown]
# **Bancing data by oversampling**

# %%
y.value_counts()
# Out:
# 0    1305
# 1     205
# Name: target, dtype: int64

# %% [markdown]
# **As we can see that the data is imbalance we can balance it by imblearn over_sampling**

# %%
# Importing Libraries for it 
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    1305
# 1    1305
# Name: target, dtype: int64

# %% [markdown]
# **we have converted the multi categorical output in only two categories as mentioned above so Binary Classification model can be used**

# %% [markdown]
# # Modelling the dataset

# %%
# importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
lr=LogisticRegression()

# %% [markdown]
# **To find best random state**

# %%
maxaccu=0
maxrs=0
for i in range(1,1000):
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.20, random_state=i)
    lr.fit(xtrain,ytrain)
    predlr=lr.predict(xtest)
    acc=accuracy_score(ytest,predlr)
    print('testing accuracy', acc, 'randon state',i)
    
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
        print('max accuracy', maxaccu , 'max_random_state', i)
# Out:
# testing accuracy 0.8084291187739464 randon state 1
# max accuracy 0.8084291187739464 max_random_state 1
# testing accuracy 0.8295019157088123 randon state 2
# max accuracy 0.8295019157088123 max_random_state 2
# testing accuracy 0.8065134099616859 randon state 3
# testing accuracy 0.8314176245210728 randon state 4
# max accuracy 0.8314176245210728 max_random_state 4
# testing accuracy 0.8122605363984674 randon state 5
# testing accuracy 0.8160919540229885 randon state 6
# testing accuracy 0.8467432950191571 randon state 7
# max accuracy 0.8467432950191571 max_random_state 7
# testing accuracy 0.8122605363984674 randon state 8
# testing accuracy 0.8122605363984674 randon state 9
# testing accuracy 0.8103448275862069 randon state 10
# testing accuracy 0.8103448275862069 randon state 11
# testing accuracy 0.8103448275862069 randon state 12
# testing accuracy 0.8256704980842912 randon state 13
# testing accuracy 0.8256704980842912 randon state 14
# ...

# %%
print('best accuracy is ',maxaccu,'best randon state is ',maxrs)
# Out:
# best accuracy is  0.8697318007662835 best randon state is  301

# %% [markdown]
# **Creating the train test split according to our best random state**

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=.20, random_state=301)

# %%
x_train.shape
# Out:
# (2088, 8)

# %%
x_test.shape
# Out:
# (522, 8)

# %%
y_train.shape
# Out:
# (2088,)

# %%
y_test.shape
# Out:
# (522,)

# %% [markdown]
# **using now Decision tree classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.9042145593869731
# [[233  32]
#  [ 18 239]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       265
#            1       0.88      0.93      0.91       257
#
#     accuracy                           0.90       522
#    macro avg       0.91      0.90      0.90       522
# weighted avg       0.91      0.90      0.90       522

# %% [markdown]
# **using Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=200)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.9559386973180076
# [[247  18]
#  [  5 252]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96       265
#            1       0.93      0.98      0.96       257
#
#     accuracy                           0.96       522
#    macro avg       0.96      0.96      0.96       522
# weighted avg       0.96      0.96      0.96       522

# %% [markdown]
# **using SVC**

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8888888888888888
# [[221  44]
#  [ 14 243]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88       265
#            1       0.85      0.95      0.89       257
#
#     accuracy                           0.89       522
#    macro avg       0.89      0.89      0.89       522
# weighted avg       0.89      0.89      0.89       522

# %% [markdown]
# **using KNN Classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.9118773946360154
# [[223  42]
#  [  4 253]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.91       265
#            1       0.86      0.98      0.92       257
#
#     accuracy                           0.91       522
#    macro avg       0.92      0.91      0.91       522
# weighted avg       0.92      0.91      0.91       522

# %% [markdown]
# **using GradientBoostingClassifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier
xgb=KNeighborsClassifier()
xgb.fit(x_train,y_train)
predxgb=xgb.predict(x_test)
print(accuracy_score(y_test,predxgb))
print(confusion_matrix(y_test,predxgb))
print(classification_report(y_test,predxgb))
# Out:
# 0.9118773946360154
# [[223  42]
#  [  4 253]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.91       265
#            1       0.86      0.98      0.92       257
#
#     accuracy                           0.91       522
#    macro avg       0.92      0.91      0.91       522
# weighted avg       0.92      0.91      0.91       522

# %% [markdown]
# **using Adaboostclassifier**

# %%
from sklearn.ensemble import AdaBoostClassifier
ada=KNeighborsClassifier()
ada.fit(x_train,y_train)
predada=ada.predict(x_test)
print(accuracy_score(y_test,predada))
print(confusion_matrix(y_test,predada))
print(classification_report(y_test,predada))
# Out:
# 0.9118773946360154
# [[223  42]
#  [  4 253]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.91       265
#            1       0.86      0.98      0.92       257
#
#     accuracy                           0.91       522
#    macro avg       0.92      0.91      0.91       522
# weighted avg       0.92      0.91      0.91       522

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# validation accuracy
model=[lr,dtc,rf,svc,knn,xgb,ada]

for i in model:
    for j in range(2,10):
        print('taking cv =', j)
        cr_score=cross_val_score(i, x, y, cv=j)
        print('Cross validation score for ' , i ,' is', cr_score)
        print('Mean of Cross Val. score is ', cr_score.mean())
# Out:
# taking cv = 2
# Cross validation score for  LogisticRegression()  is [0.83371648 0.72796935]
# Mean of Cross Val. score is  0.7808429118773946
# taking cv = 3
# Cross validation score for  LogisticRegression()  is [0.83448276 0.81494253 0.74827586]
# Mean of Cross Val. score is  0.7992337164750958
# taking cv = 4
# Cross validation score for  LogisticRegression()  is [0.86523737 0.82542113 0.71165644 0.78680982]
# Mean of Cross Val. score is  0.7972811892257536
# taking cv = 5
# Cross validation score for  LogisticRegression()  is [0.88314176 0.77011494 0.84482759 0.70881226 0.80076628]
# Mean of Cross Val. score is  0.8015325670498085
# taking cv = 6
# Cross validation score for  LogisticRegression()  is [0.89195402 0.77701149 0.86896552 0.75632184 0.74022989 0.7908046 ]
# Mean of Cross Val. score is  0.8042145593869732
# taking cv = 7
# Cross validation score for  LogisticRegression()  is [0.89812332 0.8150134  0.80697051 0.86863271 0.67024129 0.80965147
#  0.77150538]
# ...

# %% [markdown]
# **It is observed that by taking cv = 7 and with Random Forest Classifier the model is performing good**

# %% [markdown]
# # Hyper Parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

#Creating parameter list to be passed in GridSearchCV

parameters={'max_features':['auto','sqrt','log2'] , 
            'max_depth':[4,5,6,7,8],
            'criterion':['gini','entropy'], 
            'n_estimators': [100,200,300,400,500]}

# %%
GCV=GridSearchCV(estimator=RandomForestClassifier(),
                param_grid=parameters,
                cv=7,
                scoring='accuracy')

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              scoring='accuracy')

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'log2',
#  'n_estimators': 400}

# %%
GCV.best_estimator_
# Out:
# RandomForestClassifier(max_depth=8, max_features='log2', n_estimators=400)

# %%
final_model=RandomForestClassifier(criterion='gini',max_depth= 8, max_features='log2', n_estimators= 400)
final_model.fit(x_train,y_train)
predfinal=final_model.predict(x_test)
print('Final Accuracy is with Random Forest Classifier = ',accuracy_score(y_test,predfinal))
# Out:
# Final Accuracy is with Random Forest Classifier =  0.9348659003831418

# %% [markdown]
# # AUC ROC

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title('AUC ROC Curve')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Saving the Model in pickle format

# %%
import joblib
joblib.dump(GCV.best_estimator_, "Red Wine Model.pkl")
# Out:
# ['Red Wine Model.pkl']

# %% [markdown]
# # Conclusion

# %%
a=np.array(y_test)
predicted=np.array(predfinal)
df_con=pd.DataFrame({'Original':a,'Predicted':predicted}, index=range(len(a)))
df_con
# Out:
#      Original  Predicted
# 0           0          0
# 1           1          1
# 2           1          1
# 3           0          0
# 4           0          1
# ..        ...        ...
# 517         0          0
# 518         1          1
# 519         1          1
# 520         1          1
# 521         0          0
#
# [522 rows x 2 columns]
